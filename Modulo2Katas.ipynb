# %% [markdown]
# ## Crear entorno virtual

# %%
"""Crea un entorno virtual mediante venv
 Ejecutar en su terminal: python3 -m venv env
 python3: La versión de python a utilizar.
venv: Llamada al módulo venv conocido como virtual environment.
env: Nombre de nuestro entorno virtual."""

# %% [markdown]
# ### Activar el entorno virtual

# %%
"""Para usarlo, debes activarlo llamando activate a un script en tu directorio env.
Ejecutar en tu terminal <#
.Synopsis
Llamar al comando activate cambia el mensaje de salida de la consola. 
Ahora está precedido con (env) y se parece a este ejemplo:
(env) PS C:...........\Escritorio\entorno> <#
>> .Synopsis"""

# %% [markdown]
# ### Instalar un paquete

# %%
# Instalar un paquete mediante pip. 
#  Si estás desde un notebook se ejecuta así: !pip install python-dateutil 
# Ejecuta el comando pip freeze para ver las bibliotecas instaladas en tu entorno: python-dateutil==2.8.2
six==1.16.0

# %% [markdown]
# ### Desactivar un entorno virtual

# %%
# Ejecuta el comando deactivate:
# Observa cómo cambia el mensaje de tu terminal (env) a cómo se veía antes.

#¡Felicidades! Has logrado crear y usar correctamente un entorno virtual.
