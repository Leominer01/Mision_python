# %% [markdown]
# # Ejercicio 1: Transformar cadenas

# %% [markdown]
# Hay varias operaciones que puedes realizar en las cadenas cuando las manipulamos. En este ejercicio, usarás métodos de cadena para modificar el texto con hechos sobre la Luna y luego extraerás información para crear un breve resumen.

# %%
multiline = """Interesting facts about the Moon:\n The Moon is Earth's only satellite.\n There are several interesting facts about the Moon and how it affects life here on Earth.\n On average, the Moon moves 4cm away from the Earth every year.\n This yearly drift is not significant enough to cause immediate effects on Earth.\n The highest daylight temperature of the Moon is 127 C""" 
#Primero, divide el texto en cada oración para trabajar con su contenido:
print(multiline)

text ="""Interesting facts about the Moon. The Moon is Earth's only satellite. There are several interesting facts about the Moon and how it affects life here on Earth.
On average, the Moon moves 4cm away from the Earth every year. This yearly drift is not significant enough to cause immediate effects on Earth. The highest daylight temperature of the Moon is 127 C"""
# Divide el texto
text_parts = text.split('. ')
text_parts
# Out:
# Interesting facts about the Moon:
#  The Moon is Earth's only satellite.
#  There are several interesting facts about the Moon and how it affects life here on Earth.
#  On average, the Moon moves 4cm away from the Earth every year.
#  This yearly drift is not significant enough to cause immediate effects on Earth.
#  The highest daylight temperature of the Moon is 127 C
# ['Interesting facts about the Moon',
#  "The Moon is Earth's only satellite",
#  'There are several interesting facts about the Moon and how it affects life here on Earth.\nOn average, the Moon moves 4cm away from the Earth every year',
#  'This yearly drift is not significant enough to cause immediate effects on Earth',
#  'The highest daylight temperature of the Moon is 127 C']

# %%
text = """Interesting facts about the Moon. The Moon is Earth's only satellite. There are several interesting facts about the Moon and how it affects life here on Earth. 
On average, the Moon moves 4cm away from the Earth every year. This yearly drift is not significant enough to cause immediate effects on Earth. The highest daylight temperature of the Moon is 127 C"""

#Ahora, define algunas palabras clave para búsqueda que te ayudarán a determinar si una oración contiene un hecho.
'temperature' in text,'satellite'in text,'moves' in text

# Las variable es key_words = ["satellite", "moves","temperature"]
# Out:
# (True, True, True)

# %%
List =["Interesting facts about the Moon.","The Moon is Earth's only satellite.","There are several interesting facts about the Moon and how it affects life here on Earth.", 
"On average, the Moon moves 4cm away from the Earth every year.", "This yearly drift is not significant enough to cause immediate effects on Earth.", 
"The highest daylight temperature of the Moon is 127 C."]
key_words = ["satellite", "moves", "temperature"]
#Cree un bucle para imprimir solo datos sobre la Luna que estén relacionados con las palabras clave definidas anteriormente:
for sentence in List:
    for key_word in key_words:
        if key_word in sentence:
            print(sentence)
            break
# Out:
# The Moon is Earth's only satellite.
# On average, the Moon moves 4cm away from the Earth every year.
# The highest daylight temperature of the Moon is 127 C.

# %%
text1 = ["Interesting facts about the Moon.","The Moon is Earth's only satellite.",
"There are several interesting facts about the Moon and how it affects life here on Earth.", 
"On average, the Moon moves 4cm away from the Earth every year.", 
"This yearly drift is not significant enough to cause immediate effects on Earth.", 
"The highest daylight temperature of the Moon is 127 C."]

#Finalmente, actualiza el bucle(ciclo) para cambiar C a Celsius:
for sentence in text1:
    for key_word in key_word:
        if key_word in sentence:
            print(sentence.replace(' C', ' Celsius'))
            break
# Out:
# Interesting facts about the Moon.
# The Moon is Earth's only satellite.
# There are several interesting facts about the Moon and how it affects life here on Earth.
# On average, the Moon moves 4cm away from the Earth every year.
# This yearly drift is not significant enough to cause immediate effects on Earth.
# The highest daylight temperature of the Moon is 127 Celsius.

# %% [markdown]
# # Ejercicio 2: Formateando Cadenas

# %% [markdown]
# #### Datos con los que vas a trabajar
# name1 = "Moon"
# gravity1 = 0.00162 # in kms
# planet1 = "Earth"
#
# name2 = 'Ganímedes'
# gravity2  = 0.00143
# planet2 = 'Marte '

# %%
name1 = "Moon"
gravity1 = 0.00162 # in kms
planet1 = "Earth"

name2 = 'Ganímedes'
gravity2  = 0.00143
planet2 = 'Marte '

# Creamos la plantilla
template = f"""Datos de gravedad sobre: {name1} 
-------------------------------------------------------------------------------

Nombre del planeta: {planet1} 
Gravedad en {name1}: {gravity1 * 1000} m/s2 
""" 

new_template = f""" Datos de Gravedad sobre: {name2}
-------------------------------------------------------------------------------

Nombre del planeta: {planet2} 
Gravedad en {name2}: {gravity2 * 1000} m/s2 
"""
print(template)
print(new_template)
# Out:
# Datos de gravedad sobre: Moon
# -------------------------------------------------------------------------------
#
# Nombre del planeta: Earth
# Gravedad en Moon: 1.6199999999999999 m/s2
#
#  Datos de Gravedad sobre: Ganímedes
# -------------------------------------------------------------------------------
#
# Nombre del planeta: Marte
# Gravedad en Ganímedes: 1.4300000000000002 m/s2
