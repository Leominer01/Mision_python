# %% [markdown]
# # Ejercicio 1: Creación de diccionarios de Python
# Crear y modificar un diccionario de Python

# %%
# Crea un diccionario llamado planet con los datos propuestos

planet = { "name" : "Mars", "moons": 2}

    # Muestra el nombre del planeta y el número de lunas que tiene.

print(f'{planet["name"]} has {planet["moons"]} moons')
# Out:
# Mars has 2 moons

# %% [markdown]
# Puedes actualizar las claves existentes o crear otras nuevas utilizando el método update o entre corchetes ([ ]).
# demo['new_key'] = 'New value'
# Agrega un nuevo valor con una clave de 'circunferencia (km)'. Este nuevo valor debería almacenar un diccionario con las dos circunferencias del planeta:
#
# polar: 6752
# equatorial: 6792

# %%
# Agrega la clave circunferencia con los datos proporcionados previamente.
planet["circumference (km)"] = { "polar": 6752, "equatorial": 6792}

# Imprime el nombre del planeta con su circunferencia polar.
print(f'{planet["name"]} has a polar circumference of {planet["circumference (km)"]["polar"]} Km at poles and a circumference of {planet["circumference (km)"]["equatorial"]} Km equatorial.')
# Out:
# Mars has a polar circumference of 6752 Km at poles and a circumference of 6792 Km equatorial.

# %% [markdown]
# # Ejercicio 2: Programación dinámica con diccionarios
# Cálculo de valores: En este escenario, calcularás tanto el número total de lunas en el sistema solar como el número promedio de lunas que tiene un planeta.

# %% [markdown]
# Los diccionarios de Python te permiten recuperar todos los valores y claves utilizando los métodos values y keys, respectivamente. Cada método devuelve una lista que contiene los datos, que luego se puede usar como una lista normal de Python. Puedes determinar el número de elementos mediante len, e iterar a través de él mediante un ciclo for.

# %%
# Planets and moons

planet_moons = {
    'mercury': 0,
    'venus': 0,
    'earth': 1,
    'mars': 2,
    'jupiter': 79,
    'saturn': 82,
    'uranus': 27,
    'neptune': 14,
    'pluto': 5,
    'haumea': 2,
    'makemake': 1,
    'eris': 1
}
#Comienza almacenando el valor values de planet_moons en una variable denominada moons (Se agrega "names" para la práctica)
names = planet_moons.keys()

moons = planet_moons.values()
#A continuación, almacena el número de planetas en una variable denominada planets.
planets = len(planet_moons.keys())
print("El total de planetas es de: ",planets)
# Agrega el código (ciclo) a continuación para determinar el número de lunas.
total_moons = 0
for moon in moons:
    total_moons = total_moons + moon
print("El total de lunas es de: ",total_moons)

#finalmente calcule el promedio dividiendo total_moons por planets e imprimiendo los resultados.
promedio = total_moons/planets
print(" El promedio de lunas entre los planetas es de: ",promedio)
# Out:
# El total de planetas es de:  12
# El total de lunas es de:  214
#  El promedio de lunas entre los planetas es de:  17.833333333333332
